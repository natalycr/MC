# %%
% pylab inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ##Primer punto
# Función para  calcular el seno:

# %%
def numsin(n, x):
    term_sum=[0]*(n+1) # Guarda los terminos de la suma
    term_sum[1]=1.0*x #n=1
    suma= term_sum[1] # empieza la suma con el primer termino 
    for i in range (2,n+1):
        term_sum[i]= ((-x**2)/((2*i-1)*(2*i-2)))*(term_sum[i-1])
        suma+= term_sum[i]
    return suma# Guarda los terminos de la suma

# %%
#para  comprobar que funciona el método
#round(numsin(10, np.pi/2),3)
#print numsin(5,0.45454545)
#print np.sin(35.454545)

# %% [markdown]
# ##Segundo punto
#
# Para probar los diferentes valores se utiliza el siguiente recuadro.

# %% [markdown]
# Cambie el tipo de escrip de *markdown a code* si desea probar los valores
# ```python
# a= linspace(0.,45,100)
# b= a[83]
# print b
# uno=numsin(58, b)
# dos=np.sin(b)
# print dos-uno
# ```

# %% [markdown]
# A continuación se  encuentra el segundo punto corriendo hasta el termino 79 del linspace.

# %%
a= linspace(0.,45,100)
iteraciones=[]
errores_abs=[]
a_usados=[]
sumas_x=[]
reales =[]
for i in range(80): #len(a)
    real=np.sin(a[i]) # valor real del sin(x)
    m=1 # nuemro de terminos de la suma 
    nuevo= numsin(m,a[i]) # El primer nuevo a comparar
    valabs=abs(real- nuevo)
   
    while valabs > 0.01:
        m=m+1
        nuevo= numsin(m,a[i])
        valabs=abs(real- nuevo) 

    iteraciones += [m] # Guarda el numero de terminos de la suma que cumplen la condición
    errores_abs += [valabs] # Guarda últimos valores de diferencia absoluta respecto al real
    a_usados += [a[i]] # guarda el valor de x
    sumas_x += [nuevo] # guarda el resultado de la suma para ese x
    reales += [real] # guarda el sin(x)
    print i, a_usados[i], m, valabs, "SUMA", nuevo
# Out:
# 0 0.0 1 0.0 SUMA 0.0
# 1 0.454545454545 2 0.000160905093556 SUMA 0.43889306286
# 2 0.909090909091 2 0.00507368723694 SUMA 0.783871775607
# 3 1.36363636364 3 0.00169546218301 SUMA 0.980314465604
# 4 1.81818181818 4 0.000580766516503 SUMA 0.968975182666
# 5 2.27272727273 4 0.00425565242996 SUMA 0.759341160228
# 6 2.72727272727 5 0.00148385179092 SUMA 0.40405134246
# 7 3.18181818182 5 0.00795299779742 SUMA -0.0322616832002
# 8 3.63636363636 6 0.00293435628901 SUMA -0.477764467111
# 9 4.09090909091 7 0.00108282128971 SUMA -0.811934876641
# 10 4.54545454545 7 0.0051868168841 SUMA -0.980911957607
# 11 5.0 8 0.00199706601959 SUMA -0.960921340683
# 12 5.45454545455 8 0.00865085402036 SUMA -0.745663612339
# 13 5.90909090909 9 0.00345670317676 SUMA -0.361973006351
# 14 6.36363636364 10 0.00136661058262 SUMA 0.0789976890877
# 15 6.81818181818 10 0.00575469486928 SUMA 0.504083343081
# 16 7.27272727273 11 0.00234111823085 SUMA 0.838115690283
# 17 7.72727272727 11 0.00934045814163 SUMA 1.0013236192
# 18 8.18181818182 12 0.00389565663449 SUMA 0.942845523949
# 19 8.63636363636 13 0.00160466172959 SUMA 0.710840971231
# 20 9.09090909091 13 0.00635085669241 SUMA 0.334051565506
# 21 9.54545454545 14 0.0026702030791 SUMA -0.123054102035
# 22 10.0 15 0.00110995892523 SUMA -0.542911151964
# 23 10.4545454545 15 0.00436737358301 SUMA -0.852811893849
# 74 33.6363636364 46 0.00713019250533 SUMA 0.789170953565
# 75 34.0909090909 48 0.00736547257147 SUMA 0.457226832978
# 76 34.5454545455 47 0.008406632296 SUMA 0.0204709836518
# 77 35.0 48 0.0053425215789 SUMA -0.433525191075
# 78 35.4545454545 49 0.00939235789886 SUMA -0.772082587654
# 79 35.9090909091 49 0.00957300991134 SUMA -0.985639379534

# %% [markdown]
# Las  gráficas para entender porque  el metodo corre hasta 79 con 0.01 como ladiferencia mínima se  encuentran a  continuación. Las  primeras van solamente hasta

# %%
plt.figure(figsize=(13,10))

plt.subplot(311)
plt.title(' Resultados para los valores del linspace hata el [79]')
plt.xlabel('Valores de x para sin(x)')
plt.ylabel('Diferencia del valor real al de la sumatoria')
plt.plot(a_usados,errores_abs)

plt.subplot(312)
plt.xlabel('Valores de x para sin(x)')
plt.ylabel('Diferencia del valor real al de la sumatoria')
plt.plot(a_usados, iteraciones)

plt.subplot(313)
plt.xlabel('Valores de x para sin(x)')
plt.ylabel('Valor de la sumatoria')
plt.plot(a_usados, sumas_x, c='m')#, plt.plot(a_usados, reales, c='g')

# %% [markdown]
# Si aumentamos el  valor de  fiferencia a considerar el método empieza a moverse. A continuación se  muestra un ejemoplo de eso.
#
# Solo se  modifica el valor de la cota. de 0.01- 0.05

# %%
a= linspace(0.,45,100)
iteraciones_2=[]
errores_abs_2=[]
a_usados_2=[]
sumas_x_2=[]
reales_2 =[]
for i in range(85): #len(a)
    real=np.sin(a[i]) # valor real del sin(x)
    m=1 # nuemro de terminos de la suma 
    nuevo= numsin(m,a[i]) # El primer nuevo a comparar
    valabs=abs(real- nuevo)
   
    while valabs > 0.06:
        m=m+1
        nuevo= numsin(m,a[i])
        valabs=abs(real- nuevo) 

    iteraciones_2 += [m] # Guarda el numero de terminos de la suma que cumplen la condición
    errores_abs_2 += [valabs] # Guarda últimos valores de diferencia absoluta respecto al real
    a_usados_2 += [a[i]] # guarda el valor de x
    sumas_x_2 += [nuevo] # guarda el resultado de la suma para ese x
    reales_2 += [real] # guarda el sin(x)
    #if i==81:
        #print '-------------------error_para_el_metodo-----------------------------' #'Este es el problema_81_', valab
    #print i, a_usados_2[i], m, valabs, "SUMA", nuevo

# %% [markdown]
# Segundo grupo de gráficas:

# %%
plt.figure(figsize=(13,10))

plt.subplot(311)
plt.title(' Resultados para los valores del linspace hata el [84]')
plt.xlabel('Valores de x para sin(x)')
plt.ylabel('Diferencia del valor real al de la sumatoria')
plt.plot(a_usados_2,errores_abs_2)

plt.subplot(312)
plt.xlabel('Valores de x para sin(x)')
plt.ylabel('Diferencia del valor real al de la sumatoria')
plt.plot(a_usados_2, iteraciones_2)

plt.subplot(313)
plt.xlabel('Valores de x para sin(x)')
plt.ylabel('Valor de la sumatoria')
plt.plot(a_usados_2, sumas_x_2, c='m')#, plt.plot(a_usados, reales, c='g')

# %%
a= linspace(0.,45,100)
iteraciones_2=[]
errores_abs_2=[]
a_usados_2=[]
sumas_x_2=[]
reales_2 =[]
for i in range(80): #len(a)
    real=np.sin(a[i]) # valor real del sin(x)
    m=1 # nuemro de terminos de la suma 
    nuevo= numsin(m,a[i]) # El primer nuevo a comparar
    valabs=abs(real- nuevo)
    k= m+1
    print 'm', k
    netx_sum= numsin(2,a[i])
    print next_sum
    con=1
    while valabs > 0.1 and con==1:
        m=m+1
        nuevo= numsin(m,a[i])
        valabs=abs(real- nuevo) 

    iteraciones_2 += [m] # Guarda el numero de terminos de la suma que cumplen la condición
    errores_abs_2 += [valabs] # Guarda últimos valores de diferencia absoluta respecto al real
    a_usados_2 += [a[i]] # guarda el valor de x
    sumas_x_2 += [nuevo] # guarda el resultado de la suma para ese x
    reales_2 += [real] # guarda el sin(x)
    print i, a_usados[i], m, valabs, "SUMA", nuevo
# Out:
# m 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8c75097c3332> in <module>()
#      13     print 'm', k
#      14     netx_sum= numsin(2,a[i])
# ---> 15     print next_sum
#      16     con=1
#      17     while valabs > 0.1 and con==1:
#
# NameError: name 'next_sum' is not defined

# %% [markdown]
# estos son los valores de mínimos problemas.

# %%
a= linspace(0.,45,100) 
b= a[67]
print b
uno=numsin(43, b)
dos=np.sin(b)
print abs(dos-uno)
print abs(numsin(42,b)-uno)
# Out:
# 30.4545454545
# 0.000426499296285
# 0.00457749060663

# %% [markdown]
# print 'i', 'n', 'diferencia al real'
#
# for k in range (len(i_lista)):
#     print i_lista[k],  iteraciones[k], errores_abs[k]

# %%
for l in range (1):
    iteraciones=[]
    errores_abs=[]
    i_lista=[]
    cota=l*2* 0.01
    rango=79
    
    actual=array([iteraciones, errores_abs,i_lista]) 
    # este arry guarda todas las iteraciones parlas gráficas
    
    for i in range(rango): #len(a)
        real=np.sin(a[i]) # valor real del sin(x)
        m=1 # nuemro de terminos de la suma 
        nuevo= numsin(m,a[i]) # El primer nuevo a comparar
        valabs=abs(real- nuevo)
   
        while valabs > cota:
            m=m+1
            nuevo= numsin(m,a[i])
            valabs=abs(real- nuevo) 
        iteraciones += [m] # Guarda el numero de terminos de la suma que cumplen la condición
        errores_abs += [valabs]
        i_lista +=[i]
        rango = rango+1
        print actual
        #print i, a[i], m, valabs, "SUMA", nuevo
# Out:
# []
# []
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-e474a8eba316> in <module>()
#      17         while valabs > cota:
#      18             m=m+1
# ---> 19             nuevo= numsin(m,a[i])
#      20             valabs=abs(real- nuevo)
#      21         iteraciones += [m] # Guarda el numero de terminos de la suma que cumplen la condición
#
# <ipython-input-2-e067934a37ef> in numsin(n, x)
#       4     suma= term_sum[1] # empieza la suma con el primer termino
#       5     for i in range (2,n+1):
# ----> 6         term_sum[i]= ((-x**2)/((2*i-1)*(2*i-2)))*(term_sum[i-1])
#       7         suma+= term_sum[i]
#       8     return suma# Guarda los terminos de la suma
#
# KeyboardInterrupt:

# %%
a=[2,4,5]
b=[6,7,8]
c=[10,11,12,78,89]
d=[2,4,6]
e=[3,5,6,7,8,3,3,5,6,7]
f=[8,8,9,2,34,4]
#actual=array([[a],[b],[c]])
actual=array([a,b,c])
new=array([d,e,f])
print actual
print "New"
actual=np.concatenate((actual,new))
#print actual[2][3]
#print actual[0][0]
print actual
print actual[3]
# Out:
# [[2, 4, 5] [6, 7, 8] [10, 11, 12, 78, 89]]
# New
# [[2, 4, 5] [6, 7, 8] [10, 11, 12, 78, 89] [2, 4, 6]
#  [3, 5, 6, 7, 8, 3, 3, 5, 6, 7] [8, 8, 9, 2, 34, 4]]
# [2, 4, 6]
