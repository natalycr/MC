# %%
# %pylab inline
# siendo  a y  b contadores 
zerosArrayp=np.zeros((1024,1024))
r=10
a= r/2# a equivale  al radio (máximo de  pixeles)
c= len(zerosArrayp)/2# centro 
for i in range (a+1):

    b= i*2# multiplo de  4 que  depende de  4 
    #print i, b
    for j  in range (b+1):
        zerosArrayp[(c+i),(c+j)]=1
        zerosArrayp[(c-i),(c+j)]=1
        zerosArrayp[(c-i),(c-j)]=1
        zerosArrayp[(c+i),(c-j)]=1
        
        zerosArrayp[(c+j),(c+i)]=1
        zerosArrayp[(c-j),(c+i)]=1
        zerosArrayp[(c-j),(c-i)]=1
        zerosArrayp[(c+j),(c-i)]=1
        #print zerosArrayp[(c-10):(c+10)]
plt.imshow(zerosArrayp[512-20: 512+20,512-20: 512+20], cmap=cm.Greys_r)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# siendo  a y  b contadores 
zerosArrayp=np.zeros((1024,1024))
r=int(len(zerosArrayp)*0.01)
print r
r_2= r**2
# para  empesar de x,y
origen= (len(zerosArrayp)/2) -r 
for  i in range((2*r)+1):
    x= origen + i # guarda la posición en x 
    val_x= -r +i
    for  k in range ((2*r)+1):
        y= (origen +k ) # guarda la posición en y 
        val_y = -r +k
        cuadrados= val_x**2 + val_y**2
        if r_2 >= cuadrados:
            zerosArrayp[x,y]=1

plt.imshow(zerosArrayp[512-20: 512+20,512-20: 512+20], cmap=cm.Greys_r)
# Out:
# 10

# %%
#  para encontar lo minimos y maximos 
#medio=len(X)/2

max_1=max(inter_qua(X[((len(X)/2)-5):((len(X)/2)+20)]))
int_1= X[((len(X)/2)-5):((len(X)/2)+20)] # intervalo

max_2=max(inter_qua(X[((len(X)/2)+64):((len(X)/2)+96)]))
int_2= X[((len(X)/2)+64):((len(X)/2)+96)] # intervalo

max_3=max(inter_qua(X[((len(X)/2)+128):((len(X)/2)+150)]))
int_3= X[((len(X)/2)+128):((len(X)/2)+150)] # intervalo

# minimos!!
min_1= min(inter_qua(X[((len(X)/2)+32):((len(X)/2)+64)]))
int_4= X[((len(X)/2)+32):((len(X)/2)+64)]

min_2= min(inter_qua(X[((len(X)/2)+96):((len(X)/2)+128)]))
int_5= X[((len(X)/2)+96):((len(X)/2)+128)]

print max_1,'intervalo', '[',int_1[0], ':',int_1[len(int_1)-1],']'

print min_1, 'intervalo', '[',int_4[0], ':',int_4[len(int_4)-1],']'

print max_2,'intervalo', '[',int_2[0], ':',int_2[len(int_2)-1],']'

print min_2, 'intervalo', '[',int_5[0], ':',int_5[len(int_5)-1],']'

print max_3,'intervalo', '[',int_3[0], ':',int_3[len(int_3)-1],']'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-23f57732dcaf> in <module>()
#       2 #medio=len(X)/2
#       3
# ----> 4 max_1=max(inter_qua(X[((len(X)/2)-5):((len(X)/2)+20)]))
#       5 int_1= X[((len(X)/2)-5):((len(X)/2)+20)] # intervalo
#       6
#
# NameError: name 'inter_qua' is not defined
